# %%
import os
import copy
import torch
import numpy as np
import matplotlib.pyplot as plt
import torchvision
from sklearn.model_selection import train_test_split
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from PIL import Image
import torch.nn as nn
import torch.optim as optim
from torchvision.models import efficientnet_v2_s, EfficientNet_V2_S_Weights

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Load data from folder

# %%
data_path = '/kaggle/input/datasets/phnggiakhang/damaged-traffic-signs/sign_damage_v1_raw/train'

image_paths = []
labels = []

class_names = os.listdir(data_path)

for label in class_names:
    class_dir = os.path.join(data_path, label)
    for img in os.listdir(class_dir):
        image_paths.append(os.path.join(class_dir, img))
        labels.append(label)

class_names
# Out:
# ['paint_loss',
#  'normal',
#  'bent',
#  'rust',
#  'broken_sheet',
#  'graffiti',
#  'scratch',
#  'crack']

# %% [markdown]
# ### Create a custom dataset class

# %%
class CustomDataset(Dataset):
    def __init__(self, paths, labels, transform=None):
        self.paths = paths
        self.labels = labels
        self.transform = transform
        
        # consistent label encoding
        self.label_to_idx = {
            label: idx for idx, label in enumerate(sorted(set(labels)))
        }

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        img_path = self.paths[idx]
        label = self.labels[idx]

        # load image
        image = Image.open(img_path).convert("RGB")

        # apply transform
        if self.transform:
            image = self.transform(image)

        # encode label
        label = self.label_to_idx[label]

        return image, label

# %% [markdown]
# Train-test split

# %%
# Train-temp split
train_paths, temp_paths, train_labels, temp_labels = train_test_split(
    image_paths,
    labels,
    test_size=0.30,
    stratify=labels,
    random_state=42
)

# Val-test split from temp
val_paths, test_paths, val_labels, test_labels = train_test_split(
    temp_paths,
    temp_labels,
    test_size=0.50,
    stratify=temp_labels,
    random_state=42
)

print("Train:", len(train_paths))
print("Validation:", len(val_paths))
print("Test:", len(test_paths))
# Out:
# Train: 1320
# Validation: 283
# Test: 283

# %% [markdown]
# ### Calculate mean and standard deviation

# %%
# temp_train_transforms = transforms.Compose([transforms.Resize((224,224)), transforms.ToTensor()])
# temp_train_dataset = CustomDataset(image_paths, labels, transform=temp_train_transforms)
# temp_train_loader = DataLoader(dataset=temp_train_dataset, batch_size=32, shuffle=False)

# %%
# def get_mean_and_std(loader):
#     channel_sum = 0.
#     channel_sum_sq = 0.
#     total_pixels = 0

#     for images, _ in loader:
#         # images: [B, C, H, W]
#         channel_sum += images.sum(dim=[0, 2, 3])
#         channel_sum_sq += (images ** 2).sum(dim=[0, 2, 3])
#         total_pixels += images.size(0) * images.size(2) * images.size(3)

#     mean = channel_sum / total_pixels
#     std = ((channel_sum_sq / total_pixels) - (mean ** 2)).sqrt()

#     return mean, std

# %%
# mean, std = get_mean_and_std(temp_train_loader)
# print('Mean:', mean)
# print('Standard deviation:', std)

# %% [markdown]
# ### Data augmentation

# %%
# Mean and Std from ImageNet1K
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomRotation(10),
        transforms.ColorJitter(
        brightness=0.3,
        contrast=0.3,
        saturation=0.2,
        hue=0.05
    ),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(mean), torch.Tensor(std))
])

val_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(mean), torch.Tensor(std))
])

test_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(mean), torch.Tensor(std))
])

# %% [markdown]
# ### Create datasets and data loaders

# %%
train_dataset = CustomDataset(train_paths, train_labels, transform=train_transforms)
val_dataset = CustomDataset(val_paths, val_labels, transform=val_transforms)
test_dataset = CustomDataset(test_paths, test_labels, transform=test_transforms)

# %%
# Defining data loaders
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=2
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=2
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=2
)

# %% [markdown]
# ### EfficientNetV2

# %%
# Load pretrained model and weights
weights = EfficientNet_V2_S_Weights.DEFAULT
model = efficientnet_v2_s(weights=weights)

# Replace the classifier
num_classes = len(train_dataset.label_to_idx)

in_features = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.4),
    nn.Linear(in_features, 512),
    nn.BatchNorm1d(512),
    nn.ReLU(inplace=True),

    nn.Dropout(p=0.3),
    nn.Linear(512,128),
    nn.BatchNorm1d(128),
    nn.ReLU(inplace=True),

    nn.Linear(128, num_classes)
)
model = model.to(device)

# Freeze the base for transfer learning
for param in model.features.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_s-dd5fe13b.pth
# 100%|██████████| 82.7M/82.7M [00:00<00:00, 213MB/s]

# %% [markdown]
# ### Compute class weights for handling Class Imbalance

# %%
def compute_class_weights(labels, label_to_idx):
    counts = {label: 0 for label in label_to_idx}
    
    for label in labels:
        counts[label] += 1

    total = sum(counts.values())
    num_classes = len(counts)

    weights = []
    for label in sorted(label_to_idx, key=lambda x: label_to_idx[x]):
        count = counts[label]
        weight = total / (num_classes * count)
        weights.append(weight)

    return torch.tensor(weights, dtype=torch.float)

# %%
class_weights = compute_class_weights(train_labels, train_dataset.label_to_idx)
class_weights = class_weights.to(device)

# %% [markdown]
# ### Transfer learning

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Reduce LR when validation stops improving
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',        
    factor=0.4,
    patience=3,
)

# %% [markdown]
# Training loop

# %%
# Early stopping config
early_stop_patience = 7
best_val_acc = 0.0
epochs_no_improve = 0
best_model_wts = copy.deepcopy(model.state_dict())

num_epochs = 40

# %%
# Record history for plotting
history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": []
}

for epoch in range(num_epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    train_loss = running_loss / total
    train_acc = correct / total

    # Validation
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            
            val_running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)

            val_total += labels.size(0)
            val_correct += predicted.eq(labels).sum().item()

    val_loss = val_running_loss / val_total
    val_acc = val_correct / val_total

    # Save history 
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    # Scheduler step
    scheduler.step(val_acc)

    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        # Save the model
        best_model_wts = copy.deepcopy(model.state_dict())
        torch.save(model.state_dict(), "EffnetV2_transfer.pth")
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1

    print(f"Epoch {epoch+1}: Train Acc={train_acc:.4f}, Val Acc={val_acc:.4f}, Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}")

    # Early stopping
    if epochs_no_improve >= early_stop_patience:
        print("Early stopping triggered")
        break

print("Transfer learning EffNetV2 saved to /kaggle/working/EffnetV2_transfer.pth")
# Out:
# Epoch 1: Train Acc=0.1326, Val Acc=0.2403, Train Loss=2.0890, Val Loss=1.9710
# Epoch 2: Train Acc=0.2727, Val Acc=0.4311, Train Loss=1.9477, Val Loss=1.8416
# Epoch 3: Train Acc=0.3682, Val Acc=0.4947, Train Loss=1.8221, Val Loss=1.7599
# Epoch 4: Train Acc=0.4083, Val Acc=0.5300, Train Loss=1.7452, Val Loss=1.6762
# Epoch 5: Train Acc=0.4591, Val Acc=0.5512, Train Loss=1.6493, Val Loss=1.5947
# Epoch 6: Train Acc=0.5212, Val Acc=0.5654, Train Loss=1.5211, Val Loss=1.5384
# Epoch 7: Train Acc=0.5470, Val Acc=0.6113, Train Loss=1.4653, Val Loss=1.4763
# Epoch 8: Train Acc=0.5591, Val Acc=0.6396, Train Loss=1.4099, Val Loss=1.4335
# Epoch 9: Train Acc=0.5712, Val Acc=0.6572, Train Loss=1.4012, Val Loss=1.3598
# Epoch 10: Train Acc=0.6030, Val Acc=0.6714, Train Loss=1.3193, Val Loss=1.3242
# Epoch 11: Train Acc=0.6083, Val Acc=0.6926, Train Loss=1.2743, Val Loss=1.2879
# Epoch 12: Train Acc=0.6242, Val Acc=0.7279, Train Loss=1.2024, Val Loss=1.2406
# Epoch 13: Train Acc=0.6371, Val Acc=0.7385, Train Loss=1.1481, Val Loss=1.2172
# Epoch 14: Train Acc=0.6356, Val Acc=0.7244, Train Loss=1.1526, Val Loss=1.1770
# Epoch 15: Train Acc=0.6432, Val Acc=0.7385, Train Loss=1.0971, Val Loss=1.1686
# Epoch 16: Train Acc=0.6439, Val Acc=0.7456, Train Loss=1.0914, Val Loss=1.1428
# Epoch 17: Train Acc=0.6417, Val Acc=0.7491, Train Loss=1.0619, Val Loss=1.1086
# Epoch 18: Train Acc=0.6644, Val Acc=0.7491, Train Loss=1.0468, Val Loss=1.0896
# Epoch 19: Train Acc=0.6765, Val Acc=0.7597, Train Loss=1.0190, Val Loss=1.0674
# Epoch 20: Train Acc=0.6720, Val Acc=0.7491, Train Loss=0.9724, Val Loss=1.0586
# Epoch 21: Train Acc=0.6614, Val Acc=0.7633, Train Loss=1.0144, Val Loss=1.0585
# Epoch 22: Train Acc=0.6644, Val Acc=0.7562, Train Loss=0.9687, Val Loss=1.0189
# Epoch 23: Train Acc=0.7038, Val Acc=0.7597, Train Loss=0.8711, Val Loss=1.0047
# Epoch 24: Train Acc=0.6886, Val Acc=0.7668, Train Loss=0.9147, Val Loss=0.9788
# Epoch 25: Train Acc=0.6902, Val Acc=0.7633, Train Loss=0.9227, Val Loss=0.9665
# Epoch 26: Train Acc=0.6765, Val Acc=0.7703, Train Loss=0.8911, Val Loss=0.9824
# Epoch 27: Train Acc=0.7174, Val Acc=0.7562, Train Loss=0.8184, Val Loss=0.9751
# Epoch 28: Train Acc=0.7030, Val Acc=0.7633, Train Loss=0.8542, Val Loss=0.9515
# Epoch 29: Train Acc=0.6886, Val Acc=0.7739, Train Loss=0.8459, Val Loss=0.9573
# Epoch 30: Train Acc=0.7182, Val Acc=0.7809, Train Loss=0.8449, Val Loss=0.9435
# Epoch 31: Train Acc=0.7242, Val Acc=0.7951, Train Loss=0.8196, Val Loss=0.9409
# Epoch 32: Train Acc=0.7258, Val Acc=0.7845, Train Loss=0.8021, Val Loss=0.9374
# Epoch 33: Train Acc=0.7023, Val Acc=0.7774, Train Loss=0.8232, Val Loss=0.9342
# Epoch 34: Train Acc=0.7364, Val Acc=0.7951, Train Loss=0.7581, Val Loss=0.9325
# Epoch 35: Train Acc=0.7174, Val Acc=0.7951, Train Loss=0.7912, Val Loss=0.9125
# Epoch 36: Train Acc=0.7152, Val Acc=0.7880, Train Loss=0.7775, Val Loss=0.9057
# Epoch 37: Train Acc=0.7273, Val Acc=0.7915, Train Loss=0.7776, Val Loss=0.9100
# Epoch 38: Train Acc=0.7197, Val Acc=0.7951, Train Loss=0.8065, Val Loss=0.9251
# Early stopping triggered
# Transfer learning EffNetV2 saved to /kaggle/working/EffnetV2_transfer.pth

# %% [markdown]
# ### Fine-tuning

# %% [markdown]
# Loading model weights

# %%
num_classes = len(train_dataset.label_to_idx)

model = efficientnet_v2_s(weights=None)

# match your custom classifier
in_features = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.4),
    nn.Linear(in_features, 512),
    nn.BatchNorm1d(512),
    nn.ReLU(inplace=True),

    nn.Dropout(p=0.3),
    nn.Linear(512, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(inplace=True),

    nn.Linear(128, num_classes)
)

# Load trained weights
model.load_state_dict(torch.load(
    "/kaggle/working/EffnetV2_transfer.pth"
))

model = model.to(device)

# %%
# Unfreeze for fine-tuning
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the last few stages
for param in model.features[-2:].parameters():
    param.requires_grad = True

# Train the classifier
for param in model.classifier.parameters():
    param.requires_grad = True

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-5
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=0.4,
    patience=3,
)

# %%
# Fine-tune configurations
best_val_acc = 0.0
patience = 15
no_improve = 0
best_model_wts = copy.deepcopy(model.state_dict())

num_epochs = 50

# %%
# Fine-tune loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0
    train_correct = 0
    train_total = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)   
        _, preds = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (preds == labels).sum().item()
    
    train_loss = running_loss / train_total
    train_acc = train_correct / train_total
    
    # Validation
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_running_loss += loss.item() * images.size(0)  
            _, preds = torch.max(outputs, 1)

            val_total += labels.size(0)
            val_correct += (preds == labels).sum().item()

    val_acc = val_correct / val_total
    val_loss = val_running_loss / val_total

    # Save the history
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)
    
    scheduler.step(val_acc)

    print(f"Epoch {epoch+1}: Train Acc={train_acc:.4f}, Val Acc={val_acc:.4f}, Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}")

    # Early stopping
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        # Save the model
        torch.save(model.state_dict(), "/kaggle/working/EffnetV2_fine-tuned.pth")
        no_improve = 0
    else:
        no_improve += 1

    if no_improve >= patience:
        print("Early stopping")
        break

print("Fine-tuned EffNetV2 saved to /kaggle/working/EffnetV2_fine-tuned.pth")
# Out:
# Epoch 1: Train Acc=0.7129, Val Acc=0.7774, Train Loss=0.8024, Val Loss=0.8857
# Epoch 2: Train Acc=0.7455, Val Acc=0.7951, Train Loss=0.7550, Val Loss=0.8841
# Epoch 3: Train Acc=0.7515, Val Acc=0.7915, Train Loss=0.7141, Val Loss=0.8451
# Epoch 4: Train Acc=0.7508, Val Acc=0.8021, Train Loss=0.6963, Val Loss=0.8502
# Epoch 5: Train Acc=0.7553, Val Acc=0.7951, Train Loss=0.6781, Val Loss=0.8233
# Epoch 6: Train Acc=0.7735, Val Acc=0.8057, Train Loss=0.6521, Val Loss=0.8224
# Epoch 7: Train Acc=0.7727, Val Acc=0.8127, Train Loss=0.6327, Val Loss=0.8129
# Epoch 8: Train Acc=0.7833, Val Acc=0.8092, Train Loss=0.6042, Val Loss=0.8054
# Epoch 9: Train Acc=0.7909, Val Acc=0.8092, Train Loss=0.5934, Val Loss=0.8003
# Epoch 10: Train Acc=0.7955, Val Acc=0.8163, Train Loss=0.5768, Val Loss=0.7859
# Epoch 11: Train Acc=0.7909, Val Acc=0.8127, Train Loss=0.5690, Val Loss=0.7700
# Epoch 12: Train Acc=0.7750, Val Acc=0.8198, Train Loss=0.5942, Val Loss=0.7866
# Epoch 13: Train Acc=0.7992, Val Acc=0.8163, Train Loss=0.5637, Val Loss=0.7622
# Epoch 14: Train Acc=0.7947, Val Acc=0.8198, Train Loss=0.5722, Val Loss=0.7751
# Epoch 15: Train Acc=0.8121, Val Acc=0.8233, Train Loss=0.5317, Val Loss=0.7547
# Epoch 16: Train Acc=0.8144, Val Acc=0.8269, Train Loss=0.5014, Val Loss=0.7695
# Epoch 17: Train Acc=0.8242, Val Acc=0.8233, Train Loss=0.5002, Val Loss=0.7435
# Epoch 18: Train Acc=0.8182, Val Acc=0.8269, Train Loss=0.5013, Val Loss=0.7443
# Epoch 19: Train Acc=0.8220, Val Acc=0.8375, Train Loss=0.4762, Val Loss=0.7542
# Epoch 20: Train Acc=0.8220, Val Acc=0.8375, Train Loss=0.4808, Val Loss=0.7542
# Epoch 21: Train Acc=0.8280, Val Acc=0.8445, Train Loss=0.4895, Val Loss=0.7356
# Epoch 22: Train Acc=0.8356, Val Acc=0.8445, Train Loss=0.4688, Val Loss=0.7488
# Epoch 23: Train Acc=0.8364, Val Acc=0.8481, Train Loss=0.4426, Val Loss=0.7343
# Epoch 24: Train Acc=0.8356, Val Acc=0.8481, Train Loss=0.4580, Val Loss=0.7531
# Epoch 25: Train Acc=0.8515, Val Acc=0.8551, Train Loss=0.4518, Val Loss=0.7399
# Epoch 26: Train Acc=0.8364, Val Acc=0.8481, Train Loss=0.4405, Val Loss=0.7412
# Epoch 27: Train Acc=0.8485, Val Acc=0.8516, Train Loss=0.4385, Val Loss=0.7246
# Epoch 28: Train Acc=0.8462, Val Acc=0.8481, Train Loss=0.4296, Val Loss=0.7205
# Epoch 29: Train Acc=0.8568, Val Acc=0.8445, Train Loss=0.4044, Val Loss=0.7376
# Epoch 30: Train Acc=0.8591, Val Acc=0.8445, Train Loss=0.3931, Val Loss=0.7350
# Epoch 31: Train Acc=0.8417, Val Acc=0.8481, Train Loss=0.4090, Val Loss=0.7072
# Epoch 32: Train Acc=0.8598, Val Acc=0.8516, Train Loss=0.4091, Val Loss=0.7346
# Epoch 33: Train Acc=0.8674, Val Acc=0.8410, Train Loss=0.3879, Val Loss=0.7285
# Epoch 34: Train Acc=0.8515, Val Acc=0.8445, Train Loss=0.3908, Val Loss=0.7248
# Epoch 35: Train Acc=0.8515, Val Acc=0.8410, Train Loss=0.4363, Val Loss=0.7234
# Epoch 36: Train Acc=0.8621, Val Acc=0.8587, Train Loss=0.3719, Val Loss=0.7333
# Epoch 37: Train Acc=0.8697, Val Acc=0.8445, Train Loss=0.3704, Val Loss=0.7392
# Epoch 38: Train Acc=0.8553, Val Acc=0.8516, Train Loss=0.3944, Val Loss=0.7135
# Epoch 39: Train Acc=0.8417, Val Acc=0.8516, Train Loss=0.4010, Val Loss=0.7352
# Epoch 40: Train Acc=0.8697, Val Acc=0.8481, Train Loss=0.3883, Val Loss=0.7231
# Epoch 41: Train Acc=0.8576, Val Acc=0.8516, Train Loss=0.3740, Val Loss=0.7237
# Epoch 42: Train Acc=0.8568, Val Acc=0.8481, Train Loss=0.3835, Val Loss=0.7224
# Epoch 43: Train Acc=0.8697, Val Acc=0.8516, Train Loss=0.3866, Val Loss=0.7262
# Epoch 44: Train Acc=0.8720, Val Acc=0.8516, Train Loss=0.3812, Val Loss=0.7203
# Epoch 45: Train Acc=0.8705, Val Acc=0.8516, Train Loss=0.3852, Val Loss=0.7468
# Epoch 46: Train Acc=0.8629, Val Acc=0.8516, Train Loss=0.3882, Val Loss=0.7278
# Epoch 47: Train Acc=0.8780, Val Acc=0.8551, Train Loss=0.3926, Val Loss=0.7091
# Epoch 48: Train Acc=0.8629, Val Acc=0.8551, Train Loss=0.3829, Val Loss=0.7285
# Epoch 49: Train Acc=0.8545, Val Acc=0.8481, Train Loss=0.3955, Val Loss=0.7204
# Epoch 50: Train Acc=0.8492, Val Acc=0.8516, Train Loss=0.4056, Val Loss=0.7163
# Fine-tuned EffNetV2 saved to /kaggle/working/EffnetV2_fine-tuned.pth

# %% [markdown]
# ### Training History

# %%
# Loss the training loss and accuracy
plt.plot(history["train_loss"], label="train_loss")
plt.plot(history["val_loss"], label="val_loss")
plt.legend()

plt.figure()
plt.plot(history["train_acc"], label="train_acc")
plt.plot(history["val_acc"], label="val_acc")
plt.legend()

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score

def evaluate_model(model, test_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return np.array(all_labels), np.array(all_preds)

# 1. Run evaluation
y_true, y_pred = evaluate_model(model, test_loader, device)
class_names = list(train_dataset.label_to_idx.keys())

# 2. Print Detailed Classification Report
# This includes Accuracy, Precision, Recall, and F1 for every class
print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# 3. Individual Metrics (if you need them as variables)
acc = accuracy_score(y_true, y_pred)
f1_macro = f1_score(y_true, y_pred, average='macro')

print(f"Overall Accuracy: {acc:.4f}")
print(f"F1 Macro: {f1_macro:.4f}")

# 4. Confusion Matrix (Enhanced)
# We use 'true' normalization to see percentages of correct hits per class
cm = confusion_matrix(y_true, y_pred, normalize='true')

fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(xticks_rotation=45, cmap=plt.cm.Blues, ax=ax, values_format='.2f')

plt.title("Normalized Confusion Matrix")
plt.show()
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#         bent     0.8400    0.7500    0.7925        28
# broken_sheet     0.7143    0.7143    0.7143        14
#        crack     0.6250    0.8333    0.7143        12
#     graffiti     0.9846    0.9275    0.9552        69
#       normal     0.8571    0.9438    0.8984        89
#   paint_loss     1.0000    0.6250    0.7692         8
#         rust     0.9500    0.8444    0.8941        45
#      scratch     0.8500    0.9444    0.8947        18
#
#     accuracy                         0.8799       283
#    macro avg     0.8526    0.8229    0.8291       283
# weighted avg     0.8880    0.8799    0.8803       283
#
# Overall Accuracy: 0.8799
# F1 Macro: 0.8291

# %% [markdown]
# ### Stand-alone Inference Script

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torchvision.models import efficientnet_v2_s
from PIL import Image

# Class names in training order
CLASS_NAMES = [
    "bent",
    "broken_sheet",
    "crack",
    "graffiti",
    "normal",
    "paint_loss",
    "rust",
    "scratch"
]

# Rebuild the same model architecture EfficientNetV2_s
def build_model(num_classes):
    model = efficientnet_v2_s(weights=None)

    in_features = model.classifier[1].in_features

    model.classifier = nn.Sequential(
        nn.Dropout(p=0.4),
        nn.Linear(in_features, 512),
        nn.BatchNorm1d(512),
        nn.ReLU(inplace=True),

        nn.Dropout(p=0.3),
        nn.Linear(512, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(inplace=True),

        nn.Linear(128, num_classes)
    )

    return model

# Load model weights
def load_model(weight_path, device):
    model = build_model(len(CLASS_NAMES))
    model.load_state_dict(torch.load(weight_path, map_location=device))
    model.to(device)
    model.eval()
    return model

# Preprocessing
def get_transform():
    return transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        )
    ])

# Inference function
def predict_image(image_path, model, device):
    transform = get_transform()

    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)  # shape: [1, 3, 224, 224]

    with torch.no_grad():
        outputs = model(image)
        probs = torch.softmax(outputs, dim=1)
        conf, pred = torch.max(probs, 1)

    predicted_class = CLASS_NAMES[pred.item()]
    confidence = conf.item()

    return predicted_class, confidence

# Example use case
if __name__ == "__main__":
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    MODEL_PATH = "/kaggle/working/EffnetV2_fine-tuned.pth"
    IMAGE_PATH = "/kaggle/input/datasets/phnggiakhang/test-sign-scratch/new_deh_county_update_sign_pic_web.max-640x480.jpg"

    model = load_model(MODEL_PATH, DEVICE)

    pred_class, conf = predict_image(IMAGE_PATH, model, DEVICE)

    print(f"Prediction: {pred_class}")
    print(f"Confidence: {conf:.4f}")
# Out:
# Prediction: rust
# Confidence: 0.4854
